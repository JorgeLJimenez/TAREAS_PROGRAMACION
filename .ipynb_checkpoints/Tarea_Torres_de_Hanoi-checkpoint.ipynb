# %%
def hanoi(n, origen, destino, auxiliar):
    if n == 1:
        print(f"Mueve el disco 1 de {origen} a {destino}")
    else:
        hanoi(n-1, origen, auxiliar, destino)
        print(f"Mueve el disco {n} de {origen} a {destino}")
        hanoi(n-1, auxiliar, destino, origen)

'''MENÚ DE OPCIONES DE USUARIO'''
print("Bienvenido al juego de la Torre de Hanoi")
while True:
    try:
        discos = int(input("¿Con cuántos discos quiere jugar? "))
        if discos <= 0:
            print("El número de discos debe ser mayor que cero")
        else:
            break
    except ValueError:
        print("Debe ingresar un número entero")

print(f"Comenzando el juego con {discos} discos.")
print("Los movimientos a realizar son:")
hanoi(discos, "A", "C", "B")
print("Juego terminado.")
# Out:
# Bienvenido al juego de la Torre de Hanoi
# ¿Con cuántos discos quiere jugar? 7
# Comenzando el juego con 7 discos.
# Los movimientos a realizar son:
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 3 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 4 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 3 de C a B
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 5 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 3 de B a A
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 4 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 3 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 6 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 3 de C a B
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 4 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 3 de B a A
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 5 de C a B
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 3 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 4 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 3 de C a B
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 7 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 3 de B a A
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 4 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 3 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 5 de B a A
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 3 de C a B
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 4 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 3 de B a A
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 6 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 3 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 4 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 3 de C a B
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 5 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 3 de B a A
# Mueve el disco 1 de C a B
# Mueve el disco 2 de C a A
# Mueve el disco 1 de B a A
# Mueve el disco 4 de B a C
# Mueve el disco 1 de A a C
# Mueve el disco 2 de A a B
# Mueve el disco 1 de C a B
# Mueve el disco 3 de A a C
# Mueve el disco 1 de B a A
# Mueve el disco 2 de B a C
# Mueve el disco 1 de A a C
# Juego terminado.
